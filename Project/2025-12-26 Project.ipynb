# %% [markdown]
# <a href="https://colab.research.google.com/github/Kim-0718r/as-lab_colab/blob/main/Project/2025-12-26%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/as-lab_colab
# Out:
# /content/drive/MyDrive/Colab Notebooks/as-lab_colab

# %%
# Colab Git 기본 설정 (매 세션 1회)
# !git config --global user.name "Kim-0718r"
# !git config --global user.email "kim-0718r@users.noreply.github.com"

# %%
print("Hello World!")
# Out:
# Hello World!
